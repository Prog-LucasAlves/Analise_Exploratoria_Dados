# %% [markdown]
# # Dados sobre as reclamações realizadas no site:

# %% [markdown]
# ##### https://www.consumidor.gov.br/pages/principal/?1652964614719

# %% [markdown]
# ### Bibliotecas Utilizadas:

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# Versões
print('Python:', sys.version)
print('Pandas:', pd.__version__)
# Out:
# Python: 3.10.4 (tags/v3.10.4:9d38120, Mar 23 2022, 23:13:41) [MSC v.1929 64 bit (AMD64)]
# Pandas: 1.4.2

# %% [markdown]
# ### Carregando a base de dados:

# %%
# Unindo os dados dos meses de 2022(Até Abril), em apenas um DataFrame

extensao = 'csv'

arquivos_csv = [i for i in glob.glob(f'../AED_04_Consumidor_Gov_Br/data/*.{extensao}')]
df_gov = pd.concat([pd.read_csv(f, sep=';') for f in arquivos_csv])

df_gov.head()
# Out:
#   Região  UF               Cidade Sexo        Faixa Etária Data Finalização  \
# 0     S   SC        Florianópolis    M  entre 51 a 60 anos       2022-01-19
# 1     NE  MA                Timon    M     mais de 70 anos       2022-01-01
# 2     S   RS          Santa Maria    M  entre 21 a 30 anos       2022-01-01
# 3     NE  BA  Teixeira de Freitas    M  entre 21 a 30 anos       2022-01-01
# 4     SE  RJ       Rio de Janeiro    M  entre 41 a 50 anos       2022-01-04
#
#    Tempo Resposta                       Nome Fantasia  \
# 0             NaN  Banco BV (antigo Banco Votorantim)
# 1             NaN                             Oi Fixo
# 2            10.0                   Vivo - Telefônica
# 3             NaN                                Uber
# 4             NaN             Central Nacional Unimed
#
#                                  Segmento de Mercado                  Área  \
# 0    Bancos, Financeiras e Administradoras de Cartão  Serviços Financeiros
# 1  Operadoras de Telecomunicações (Telefonia, Int...      Telecomunicações
# 2  Operadoras de Telecomunicações (Telefonia, Int...      Telecomunicações
# 3   Empresas de Intermediação de Serviços / Negócios      Demais Serviços
# 4  Operadoras de Planos de Saúde e Administradora...                 Saúde
#
#                                              Assunto          Grupo Problema  \
# 0               Financiamentos de Veículos / Leasing  Cobrança / Contestação
# 1                                      Internet Fixa       Atendimento / SAC
# 2                                      Internet Fixa  Cobrança / Contestação
# 3                    Aplicativo de mobilidade urbana       Contrato / Oferta
# 4  Plano de Saúde (convênio, autogestão, seguro s...       Atendimento / SAC
#
#                                             Problema   Como Comprou Contratou  \
# 0  Cobrança por serviço/produto não contratado / ...              Loja física
# 1  Dificuldade de contato / acesso a outros canai...                 Internet
# 2  Cobrança em duplicidade / Cobrança referente a...                 Internet
# 3  Dificuldade para contratar o serviço (problema...  Não comprei / contratei
# 4  SAC - Demanda não resolvida / não respondida /...                Domicílio
#
#   Procurou Empresa Respondida                 Situação Avaliação Reclamação  \
# 0                S          N      Finalizada avaliada        Não Resolvida
# 1                S          N  Finalizada não avaliada         Não Avaliada
# 2                S          S  Finalizada não avaliada         Não Avaliada
# 3                S          N  Finalizada não avaliada         Não Avaliada
# 4                S          N  Finalizada não avaliada         Não Avaliada
#
#    Nota do Consumidor
# 0                 1.0
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Verificando a quantidade de linhas e colunas
df_gov.shape
# Out:
# (513283, 19)

# %%
# Criando a variavel 'Solicitação' aonde cada linha vai receber o numero 1 como identificação
df_gov['Solicitação'] = 1

# %%
# Verificando o nome das colunas
df_gov.columns
# Out:
# Index(['Região', 'UF', 'Cidade', 'Sexo', 'Faixa Etária', 'Data Finalização',
#        'Tempo Resposta', 'Nome Fantasia', 'Segmento de Mercado', 'Área',
#        'Assunto', 'Grupo Problema', 'Problema', 'Como Comprou Contratou',
#        'Procurou Empresa', 'Respondida', 'Situação', 'Avaliação Reclamação',
#        'Nota do Consumidor', 'Solicitação'],
#       dtype='object')

# %% [markdown]
# #### Verificar a quantidade de solicitações(Reclamações) por Região

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,4))
sns.countplot(data=df_gov, x='Região', order = df_gov['Região'].value_counts().index)
plt.title('Qtd. de Reclamações por Região')
plt.xlabel('Região')
plt.ylabel('Qtd.')
plt.show()

# %% [markdown]
# #### Verificar a quantidade de solicitações(Reclamações) por Estado

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,8))
sns.countplot(data=df_gov, y='UF',order = df_gov['UF'].value_counts().index)
plt.title('Qtd. de Reclamações por UF')
plt.xlabel('Qtd.')
plt.ylabel('UF')
plt.show()

# %% [markdown]
# #### Verificar a quantidade de solicitações(Reclamações) por sexo

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,4))
sns.countplot(data=df_gov, x='Sexo')
plt.title('Qtd. de Reclamações por Sexo')
plt.xlabel('Sexo')
plt.ylabel('Qtd.')
plt.show()

# %% [markdown]
# #### Verificar a quantidade de solicitações(Reclamações) por faixa de idade

# %%
df_gov['Faixa Etária'] = df_gov['Faixa Etária'].str.replace('entre','', regex=True)  

plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,4))
sns.countplot(data=df_gov, y='Faixa Etária',order = df_gov['Faixa Etária'].value_counts().index)
plt.title('Qtd. de Reclamações por Faixa Etária')
plt.xlabel('Qtd.')
plt.ylabel('Faixa Etária')
plt.show()

# %% [markdown]
# #### Verificar a quantidade de solicitações(Reclamações) por Segmento de Mercado

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,15))
sns.countplot(data=df_gov, y='Segmento de Mercado',order = df_gov['Segmento de Mercado'].value_counts().index)
plt.title('Qtd. de Reclamações por Segmento de Mercado')
plt.xlabel('Qtd.')
plt.ylabel('Segmento de Mercado')
plt.show()

# %%
# Porcentagem de solicitações respondidas ou não

total = df_gov['Respondida'].count()
freq_resposta = df_gov['Respondida'].value_counts()
freq_poec = round(df_gov['Respondida'].value_counts(normalize=True) * 100,2)

print("Total de Reclamações(Até 04/2022):",total)
print(f'Reclamações Respondidas:',freq_resposta[0], '-', freq_poec[0])
print(f'Reclamações Respondidas:',freq_resposta[1], '-', freq_poec[1])
# Out:
# Total de Reclamações(04/2022): 513283
# Reclamações Respondidas: 503337 - 98.06
# Reclamações Respondidas: 9946 - 1.94

# %%
df_filtro_seg_mercado = df_gov[['Segmento de Mercado','Solicitação','Respondida']]
df_filtro_seg_mercado_s = df_filtro_seg_mercado['Respondida'] == 'S'
df_filtro_seg_mercado_2 = df_filtro_seg_mercado[df_filtro_seg_mercado_s]
df_filtro_seg_mercado_group = df_filtro_seg_mercado_2.groupby(['Segmento de Mercado']).count()
df_filtro_seg_mercado_2 = df_gov[['Segmento de Mercado','Solicitação']]
df_filtro_seg_mercado_2_group = df_filtro_seg_mercado_2.groupby(['Segmento de Mercado']).count()
df_filtro_seg_mercado_2_group['Respondida'] = df_filtro_seg_mercado_group['Respondida']
df_filtro_seg_mercado_2_group.fillna(0, inplace=True)
df_filtro_seg_mercado_2_group['Respondida'] = df_filtro_seg_mercado_2_group['Respondida'].astype(np.int64)
df_filtro_seg_mercado_2_group['% Respondida'] = round(df_filtro_seg_mercado_2_group['Respondida'] / df_filtro_seg_mercado_2_group['Solicitação'] * 100, 2) 
df_filtro_seg_mercado_2_group.sort_values(by='% Respondida')
# Out:
#                                                     Solicitação  Respondida  \
# Segmento de Mercado
# Bares, Restaurantes, Casas Noturnas e Similares               2           0
# Hospitais, Clínicas, Laboratórios e Outros Serv...            4           0
# Entidades Sem Fins Lucrativos                                50          20
# Transporte Terrestre                                        411         276
# Agua e Saneamento                                          4123        2892
# Entretenimento                                             1199         860
# Shopping Centers                                              6           5
# Fabricantes - Produtos Químicos e Farmacêuticos              15          13
# Editoras e Veículos de Imprensa                             879         794
# Supermercados                                              1314        1234
# Transporte Aéreo                                          54937       52287
# Distribuidoras de Combustíveis / Gás                        897         854
# Estabelecimentos de Ensino                                 5018        4800
# Varejo                                                     5246        5041
# Fabricantes - Eletroportáteis e Artigos de Uso ...         2151        2071
# Operadoras de Planos de Saúde e Administradoras...         4243        4105
# Material de Construção, Acabamento e Ferramentas            475         460
# Empresas de Serviços Postais e Logística                   2726        2649
# Comércio Eletrônico                                       42285       41127
# Montadoras, Concessionárias e Prestadores de Se...         1498        1458
# Corretoras e Distribuidoras de Títulos e Invest...          842         820
# Vestuário, Calçados e Acessórios                           4465        4350
# Fabricantes - Produtos Alimentícios                         393         383
# Farmácias                                                  1722        1683
# Empresas de Intermediação de Serviços / Negócios          14606       14289
# Seguros, Capitalização e Previdência                      18268       17971
# Administradoras de Consórcios                              1677        1650
# Construtoras, Incorporadoras e Imobiliárias                 814         801
# Cartões de Descontos                                        634         624
# Fabricantes - Eletroeletrônicos,  Produtos de T...        14340       14119
# Viagens, Turismo e Hospedagem                             21410       21124
# Perfumaria, Cosméticos e Higiene Pessoal                   2248        2220
# Fabricantes - Móveis, Colchões e Acessórios                  82          81
# Bancos, Financeiras e Administradoras de Cartão          137666      136244
# Energia Elétrica                                          16196       16097
# Aluguel de Carros                                           868         863
# Provedores de Conteúdo e Outros Serviços na Int...        12150       12081
# Fabricantes - Linha Branca                                 2005        1996
# Empresas de Pagamento Eletrônico                          23048       22950
# Serviços Esportivos                                         708         705
# Programas de Fidelidade                                    9021        8984
# Operadoras de Telecomunicações (Telefonia, Inte...        91363       91089
# Empresas de Recuperação de Crédito                         2548        2544
# Bancos de Dados e Cadastros de Consumidores                8730        8723
#
#                                                     % Respondida
# Segmento de Mercado
# Bares, Restaurantes, Casas Noturnas e Similares             0.00
# Hospitais, Clínicas, Laboratórios e Outros Serv...          0.00
# Entidades Sem Fins Lucrativos                              40.00
# Transporte Terrestre                                       67.15
# Agua e Saneamento                                          70.14
# Entretenimento                                             71.73
# Shopping Centers                                           83.33
# Fabricantes - Produtos Químicos e Farmacêuticos            86.67
# Editoras e Veículos de Imprensa                            90.33
# Supermercados                                              93.91
# Transporte Aéreo                                           95.18
# Distribuidoras de Combustíveis / Gás                       95.21
# Estabelecimentos de Ensino                                 95.66
# Varejo                                                     96.09
# Fabricantes - Eletroportáteis e Artigos de Uso ...         96.28
# Operadoras de Planos de Saúde e Administradoras...         96.75
# Material de Construção, Acabamento e Ferramentas           96.84
# Empresas de Serviços Postais e Logística                   97.18
# Comércio Eletrônico                                        97.26
# Montadoras, Concessionárias e Prestadores de Se...         97.33
# Corretoras e Distribuidoras de Títulos e Invest...         97.39
# Vestuário, Calçados e Acessórios                           97.42
# Fabricantes - Produtos Alimentícios                        97.46
# Farmácias                                                  97.74
# Empresas de Intermediação de Serviços / Negócios           97.83
# Seguros, Capitalização e Previdência                       98.37
# Administradoras de Consórcios                              98.39
# Construtoras, Incorporadoras e Imobiliárias                98.40
# Cartões de Descontos                                       98.42
# Fabricantes - Eletroeletrônicos,  Produtos de T...         98.46
# Viagens, Turismo e Hospedagem                              98.66
# Perfumaria, Cosméticos e Higiene Pessoal                   98.75
# Fabricantes - Móveis, Colchões e Acessórios                98.78
# Bancos, Financeiras e Administradoras de Cartão            98.97
# Energia Elétrica                                           99.39
# Aluguel de Carros                                          99.42
# Provedores de Conteúdo e Outros Serviços na Int...         99.43
# Fabricantes - Linha Branca                                 99.55
# Empresas de Pagamento Eletrônico                           99.57
# Serviços Esportivos                                        99.58
# Programas de Fidelidade                                    99.59
# Operadoras de Telecomunicações (Telefonia, Inte...         99.70
# Empresas de Recuperação de Crédito                         99.84
# Bancos de Dados e Cadastros de Consumidores                99.92
